# %%
import sys
print(sys.version)
sys.path.append("../")

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use("grayscale")

plt.rcParams["figure.dpi"] = 300
import seaborn as sns
# sns.set_style("dark")
# sns.set_palette(sns.color_palette("BuGn_r"))
import statsmodels.api as sm

from statsmodels.tsa.stattools import grangercausalitytests

from datetime import datetime

import scipy.stats as stats

sys.path.append("../data_proc")

import data_proc.rpna_processing as utils

# import pandas_profiling
# Out:
# 3.7.3 (default, Dec 13 2019, 19:58:14)
# [Clang 11.0.0 (clang-1100.0.33.17)]

# %%
# Load crude oil dataset
df_oil = pd.read_csv("../data/ravenpack/crude_oil_all.csv")

# %%
df_oil.head()
# Out:
#              TIMESTAMP_UTC  RPNA_DATE_UTC RPNA_TIME_UTC RP_ENTITY_ID  \
# 0  2000-01-01 10:08:00.000       20000101  10:08:00.000       FD9CFE
# 1  2000-01-01 10:08:00.000       20000101  10:08:00.000       FD9CFE
# 2  2000-01-03 07:00:00.000       20000103  07:00:00.000       FD9CFE
# 3  2000-01-04 05:00:00.000       20000104  05:00:00.000       FD9CFE
# 4  2000-01-04 07:46:00.000       20000104  07:46:00.000       FD9CFE
#
#   ENTITY_TYPE ENTITY_NAME  POSITION_NAME  RP_POSITION_ID COUNTRY_CODE  \
# 0        CMDT   Crude Oil            NaN             NaN           XX
# 1        CMDT   Crude Oil            NaN             NaN           XX
# 2        CMDT   Crude Oil            NaN             NaN           XX
# 3        CMDT   Crude Oil            NaN             NaN           XX
# 4        CMDT   Crude Oil            NaN             NaN           XX
#
#    RELEVANCE  ... G_ENS_SIMILARITY_GAP                         G_ENS_KEY  \
# ...

# %%
mask = np.array([x.startswith("20190") for x in df_oil.RPNA_DATE_UTC.astype(str)])
df_oil[mask]
# Out:
#                   TIMESTAMP_UTC  RPNA_DATE_UTC RPNA_TIME_UTC RP_ENTITY_ID  \
# 103777  2019-01-02 16:40:11.003       20190102  16:40:11.003       FD9CFE
# 103778  2019-01-02 16:49:17.149       20190102  16:49:17.149       FD9CFE
# 103779  2019-01-02 16:55:10.938       20190102  16:55:10.938       FD9CFE
# 103780  2019-01-02 17:08:30.070       20190102  17:08:30.070       FD9CFE
# 103781  2019-01-02 17:13:19.809       20190102  17:13:19.809       FD9CFE
# ...                         ...            ...           ...          ...
# 106625  2019-08-30 19:17:34.475       20190830  19:17:34.475       FD9CFE
# 106626  2019-08-30 19:17:34.493       20190830  19:17:34.493       FD9CFE
# 106627  2019-08-30 19:17:35.005       20190830  19:17:35.005       FD9CFE
# 106628  2019-08-30 19:17:35.025       20190830  19:17:35.025       FD9CFE
# 106629  2019-08-30 22:52:05.554       20190830  22:52:05.554       FD9CFE
#
#        ENTITY_TYPE ENTITY_NAME  POSITION_NAME  RP_POSITION_ID COUNTRY_CODE  \
# ...

# %%
df_oil.ENTITY_NAME
# Out:
# 0         Crude Oil
# 1         Crude Oil
# 2         Crude Oil
# 3         Crude Oil
# 4         Crude Oil
#             ...
# 106955    Crude Oil
# 106956    Crude Oil
# 106957    Crude Oil
# 106958    Crude Oil
# 106959    Crude Oil
# Name: ENTITY_NAME, Length: 106960, dtype: object

# %%
for c in [
    "ENTITY_TYPE", "ENTITY_NAME", "POSITION_NAME",
    "SUB_TYPE", "PROPERTY", "RELEVANCE"
]:
    print("===========================")
    print(df_oil[c].value_counts())
# Out:
# ...
# CMDT    106960
# Name: ENTITY_TYPE, dtype: int64
# ...
# Crude Oil    106960
# Name: ENTITY_NAME, dtype: int64
# ...
# Series([], Name: POSITION_NAME, dtype: int64)
# ...
# loss          39293
# gain          34541
# increase       8422
# decrease       7050
# up             4345
# down           3329
# buy            1171
# unchanged       453
# offer           429
# upgrade         353
# sell            303
# downgrade       261
# resistance      150
# lifted           97
# attack           32
# suspended         8
# set               7
# close             6
# open              5
# contained         4
# sale              3
# threat            1
# ended             1
# released          1
# support           1
# Name: SUB_TYPE, dtype: int64
# ...
# commodity           17863
# target               1903
# bearish              1322
# bullish               194
# oversold               85
# output                 35
# overbought             16
# target-commodity        4
# Name: PROPERTY, dtype: int64
# ...

# %%
plt.rcParams["figure.figsize"] = (15, 3)
plt.rcParams["figure.dpi"] = 300
plt.rcParams["axes.grid"] = True
sns.distplot(df_oil.ESS, bins=100, kde=True, label="Event Sentiment Score")
plt.legend()
plt.show()

# %%
plt.rcParams["figure.dpi"] = 300
color = sns.cubehelix_palette(16, start=.5, rot=-.75, reverse=True, hue=0)
chart = sns.catplot(x="ENS", kind="count", data=df_oil, palette=color)
chart.set_xlabels("ENS: Event Novelty Score")
chart.savefig("../figures/rpna_eda/{}.png".format("ENS"), bbox_inches="tight", dpi=300)
plt.show()

# %%
chart = sns.catplot(x="G_ENS", kind="count", data=df_oil, palette=color)
chart.set_xlabels("G_ENS: Global Event Novelty Score")
chart.savefig("../figures/rpna_eda/{}.png".format("G_ENS"), dpi=300)
plt.show()

# %%
# Construct daily mannually.
df_num_news = df_oil.groupby(df_oil.RPNA_DATE_UTC).size()

# %%
df_num_news.index = pd.to_datetime(df_num_news.index.values, format="%Y%m%d")

# %%
df_num_news.index = pd.to_datetime(df_num_news.index)
print(df_num_news.head())
day_of_week_avg = df_num_news.groupby(df_num_news.index.day_name()).mean()
print(df_num_news.index.day_name())
print(day_of_week_avg.head(7))
# Out:
# 2000-01-01    2
# 2000-01-03    1
# 2000-01-04    6
# 2000-01-05    1
# 2000-01-06    3
# dtype: int64
# Index(['Saturday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        ...
#        'Friday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday'],
#       dtype='object', length=6010)
# Friday       16.729862
# Monday       17.448919
# Saturday      2.054348
# Sunday        2.423954
# Thursday     19.594358
# Tuesday      20.730019
# Wednesday    27.995127
# dtype: float64

# %%
# up sample (aggregate) to daily level.
daily, df_ESS, df_WESS = utils.main(df_oil, threshold=(0, 0))
daily = daily.asfreq("B")
# Out:
# Check the counts using two criterions:
# Percentage same:  90.74 %

# %%
daily.head()
# Out:
#              ESS_MEAN  ESS_TOTAL  WESS_MEAN  WESS_TOTAL  NUM_EVENTS  \
# DATE
# 2000-01-03  18.000000       18.0  18.000000   18.000000         1.0
# 2000-01-04   6.857143       48.0   4.975714   34.830002         7.0
# 2000-01-05  -6.000000      -12.0  -6.000000  -12.000000         2.0
# 2000-01-06 -26.500000      -53.0 -26.500000  -53.000000         2.0
# 2000-01-07 -15.000000      -60.0 -10.762500  -43.049999         4.0
#
#             NUM_POSITIVE_ESS  NUM_NEGATIVE_ESS  NUM_NEUTRAL_ESS  \
# DATE
# 2000-01-03               1.0               0.0              0.0
# 2000-01-04               4.0               2.0              1.0
# 2000-01-05               1.0               1.0              0.0
# 2000-01-06               0.0               2.0              0.0
# 2000-01-07               0.0               4.0              0.0
#
#             NUM_POSITIVE_WESS  NUM_NEGATIVE_WESS  NUM_NEUTRAL_WESS
# DATE
# 2000-01-03                1.0                0.0               0.0
# ...

# %%
daily[daily["NUM_EVENTS"].isnull()]
# Out:
#             ESS_MEAN  ESS_TOTAL  WESS_MEAN  WESS_TOTAL  NUM_EVENTS  \
# DATE
# 2001-01-02       NaN        NaN        NaN         NaN         NaN
# 2001-04-13       NaN        NaN        NaN         NaN         NaN
# 2002-01-04       NaN        NaN        NaN         NaN         NaN
# 2002-03-01       NaN        NaN        NaN         NaN         NaN
# 2002-03-22       NaN        NaN        NaN         NaN         NaN
# 2002-09-02       NaN        NaN        NaN         NaN         NaN
# 2002-09-05       NaN        NaN        NaN         NaN         NaN
# 2002-10-09       NaN        NaN        NaN         NaN         NaN
# 2002-10-31       NaN        NaN        NaN         NaN         NaN
# 2002-11-04       NaN        NaN        NaN         NaN         NaN
# 2002-11-15       NaN        NaN        NaN         NaN         NaN
# 2002-11-21       NaN        NaN        NaN         NaN         NaN
# 2002-11-27       NaN        NaN        NaN         NaN         NaN
# ...

# %%
plot_objects = {
    "Average Daily ESS": daily.ESS_MEAN,
    "Log Total Daily ESS": np.log(daily.ESS_TOTAL),
    "Number of Daily Report": daily.NUM_EVENTS
}

# %%
[x.replace(" ", "_") for x in plot_objects.keys()]
# Out:
# ['Average_Daily_ESS', 'Log_Total_Daily_ESS', 'Number_of_Daily_Report']

# %%
for k, v in plot_objects.items():
    sns.distplot(v, axlabel=k)
    plt.savefig("eda_figures/crude_oil/{}.png".format(k.replace(" ", "_")))
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-18-529ac875a662> in <module>
#       1 for k, v in plot_objects.items():
# ----> 2     sns.distplot(v, axlabel=k)
#       3     plt.savefig("eda_figures/crude_oil/{}.png".format(k.replace(" ", "_")))
#       4     plt.grid(True)
#       5     plt.show()
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     215     if hist:
#     216         if bins is None:
# --> 217             bins = min(_freedman_diaconis_bins(a), 50)
#     218         hist_kws.setdefault("alpha", 0.4)
#     219         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~/Library/Python/3.7/lib/python/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
# ...

# %%
sm.tsa.graphics.month_plot(df_num_news.values, dates=df_num_news.index)
plt.savefig("../figures/rpna_eda/rpna_monthly_plot.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
set(daily.index.day_name())
# Out:
# {'Friday', 'Monday', 'Thursday', 'Tuesday', 'Wednesday'}

# %%
print(np.mean(daily.ESS_MEAN.isnull()))
series = daily.ESS_MEAN.dropna()
print(len(series))
sm.tsa.graphics.plot_acf(series, lags=64, zero=False)
plt.savefig("../figures/rpna_eda/ess_acf.png", dpi=300, bbox_inches="tight")
plt.show()
sm.tsa.graphics.plot_pacf(series, lags=64, zero=False)
plt.savefig("../figures/rpna_eda/ess_pacf.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# 0.011209895632006184
# 5116

# %%
print(np.mean(daily.WESS_MEAN.isnull()))

series = daily.WESS_MEAN.dropna()
sm.tsa.graphics.plot_acf(series, lags=64, zero=False)
plt.savefig("../figures/rpna_eda/wess_acf.png", dpi=300, bbox_inches="tight")
plt.show()
sm.tsa.graphics.plot_pacf(series, lags=64, zero=False)
plt.savefig("../figures/rpna_eda/wess_pacf.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# 0.011209895632006184

# %%
df_num_news = pd.DataFrame(df_num_news)
df_num_news.columns = ["NUM_EVENTS"]

# %%
df_num_news = df_num_news.asfreq("D").fillna(0)

# %%
day_counts = df_num_news.groupby(df_num_news.index.day_name())["NUM_EVENTS"].sum()
num_days = df_num_news.groupby(df_num_news.index.day_name())["NUM_EVENTS"].size()
num_days
# Out:
# Friday       1034
# Monday       1035
# Saturday     1035
# Sunday       1035
# Thursday     1035
# Tuesday      1035
# Wednesday    1035
# Name: NUM_EVENTS, dtype: int64

# %%
day_counts = pd.DataFrame(day_counts)
day_counts["Day of Week"] = day_counts.index
day_counts["Average Number of Events"] = day_counts["NUM_EVENTS"].values / num_days.values
day_counts
# Out:
#            NUM_EVENTS Day of Week  Average Number of Events
# Friday        17031.0      Friday                 16.470986
# Monday        17763.0      Monday                 17.162319
# Saturday        756.0    Saturday                  0.730435
# Sunday         1275.0      Sunday                  1.231884
# Thursday      20143.0    Thursday                 19.461836
# Tuesday       21269.0     Tuesday                 20.549758
# Wednesday     28723.0   Wednesday                 27.751691

# %%
plt.rcParams["figure.dpi"] = 300
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Day of Week", y="Average Number of Events", kind="bar",
            data=day_counts,
            order=["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"],
            palette=color)
chart.set_xticklabels(rotation=45)
# chart.savefig("eda_figures/crude_oil/{}.png".format("Count_Days"))
plt.savefig("../figures/rpna_eda/{}.png".format("Count_Days"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # With Oil Price

# %%
df_returns = wti = pd.read_csv(
    "../data/ready_to_use/returns_norm.csv",
    index_col=0,
    header=0,
    parse_dates=["DATE"],
    date_parser=lambda d: datetime.strptime(d, "%Y-%m-%d")
)

# %%
wti = pd.read_csv(
    "../data/ready_to_use/DCOILWTICO.csv",
    index_col=0,
    header=0,
    parse_dates=["DATE"],
    date_parser=lambda d: datetime.strptime(d, "%Y-%m-%d")
)

# %%
d1 = np.sign(wti.diff().dropna())
d1 = d1.astype(np.int32)
d1.info()
d2 = pd.DataFrame(daily["WESS_MEAN"] >= 0)
d2 = d2[np.logical_and(d2.index >= datetime(2000,1,4), d2.index <= datetime(2019,9,30))]
d2 = d2.astype(np.int32)
d2.info()
a1 = d1.values.squeeze()
a2 = d2.values.squeeze()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4801 entries, 2000-01-05 to 2019-10-31
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DCOILWTICO  4801 non-null   int32
# dtypes: int32(1)
# memory usage: 56.3 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5150 entries, 2000-01-04 to 2019-09-30
# Freq: B
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WESS_MEAN  5150 non-null   int32
# dtypes: int32(1)
# memory usage: 60.4 KB

# %%
d1 = daily["ESS_MEAN"]
# d2 = wti.diff()["DCOILWTICO"]
d2 = df_returns["RETURN"]
idx = d1.index.intersection(d2.index)
idx = idx[-196:-64]

from sklearn.preprocessing import MinMaxScaler, StandardScaler
def squeeze(array):
    scaler = StandardScaler((-1, 1))
    return scaler.fit_transform(array)
a1 = squeeze(d1[idx].values.reshape(-1, 1))
a2 = squeeze(d2[idx].values.reshape(-1, 1))

# %%
plt.rcParams["figure.dpi"] = 300
plt.plot(idx, a1, linewidth=1.7, alpha=1, label="Aggregate News Sentiment")
plt.plot(idx, a2, linewidth=1.7, alpha=1, linestyle="-.", label="Crude Oil Return")
plt.legend()
plt.grid(True)
plt.savefig("../figures/price_ess_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
d1 = d1.values[1:]
d2 = d2.values

# %%
mask = np.logical_and(
    ~ np.isnan(d1),
    ~ np.isnan(d2)
)

# %%
print(stats.spearmanr(d1[mask], d2[mask]))
# Out:
# SpearmanrResult(correlation=0.5622500202266828, pvalue=0.0)

# %%
d2[mask].shape
# Out:
# (4940,)

# %%
d3 = np.concatenate([a1[mask].reshape(-1,1), a2[mask].reshape(-1,1)], axis=1)

# %%
a3.shape
# Out:
# (127, 2)

# %%
gc_res = grangercausalitytests(a3, 1)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.2018  , p=0.0760  , df_denom=123, df_num=1
# ssr based chi2 test:   chi2=3.2799  , p=0.0701  , df=1
# likelihood ratio test: chi2=3.2379  , p=0.0720  , df=1
# parameter F test:         F=3.2018  , p=0.0760  , df_denom=123, df_num=1

# %%
"""
Benchmark Models
"""
import numpy as np
import pandas as pd

from datetime import datetime

import statsmodels.api as sm
from statsmodels import tsa
from statsmodels.tsa.api import VAR
from statsmodels.tsa.arima_model import ARIMA

from statsmodels.tsa.statespace.sarimax import SARIMAX

import matplotlib.pyplot as plt

from data_feed import direct_feed
from training_utils import directional_accuracy, mape, mse

plt.style.use("grayscale")
plt.rcParams["figure.dpi"] = 300
plt.rcParams["figure.figsize"] = (9, 3)

# %%
data_src = "../data/ready_to_use/feature_target_2020-04-05-14:13:42.csv"
rpna_dir = "../data/ready_to_use/rpna_r0_all.csv"
figure_dir = "../figures/tsa_figures/"

# %%
df_news = pd.read_csv(
    rpna_dir,
    index_col=0,
    header=0,
    parse_dates=["DATE"],
    date_parser=lambda d: datetime.strptime(d, "%Y-%m-%d")
)

# %%
# ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
X_train, X_test, y_train, y_test = direct_feed(
    src=data_src,
    test_start=pd.to_datetime("2020-01-01"),
    day=None,
    return_array=False
)
print(f"X_train @ {X_train.shape}")
print(f"y_train @ {y_train.shape}")
print(f"X_test @ {X_test.shape}")
print(f"y_test @ {y_test.shape}")
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)
# Out:
# Dropped rows involving Nan: 2
# X_train @ (4932, 416)
# y_train @ (4932,)
# X_test @ (0, 416)
# y_test @ (0,)

# %%
df_train = pd.DataFrame(y_train.copy())
y_train = y_train.values
df_test = pd.DataFrame(y_test.copy())
y_test = y_test.values

# %%
# Construct moving window predictors.
for w in [5, 25, 50, 100]:
    df_train[f"MA_{w}"] = df_train["TARGET"].shift(1).rolling(window=w).mean()
df_train.fillna(value=0.0, inplace=True)
df_train["NAIVE"] = 0.0

# %%
df_train.iloc[4500:,:].plot()
plt.show()

# %%
df_train.tail()
# Out:
#               TARGET      MA_5     MA_25     MA_50    MA_100  NAIVE
# 2019-09-23  0.440220 -0.768089 -0.179106 -0.282382 -0.202657    0.0
# 2019-09-24 -2.536587 -1.625116 -0.184910 -0.275579 -0.205172    0.0
# 2019-09-25 -1.478900 -0.876709 -0.320228 -0.318598 -0.226142    0.0
# 2019-09-26 -0.248624 -0.808069 -0.375114 -0.284439 -0.212198    0.0
# 2019-09-27 -0.516981 -0.857794 -0.347144 -0.256411 -0.218402    0.0

# %%
def evaluate(predictor: str):
    y_true = df_train["TARGET"]
    y_pred = df_train[predictor]
    print(f"========{predictor}========")
    print(f"MSE: {mse(y_true, y_pred)}")
    print(f"Directional Accuracy: {directional_accuracy(y_true, y_pred)}")
    print(f"MAPE: {mape(y_true, y_pred)}")

# %%
predictor_lst = [c for c in df_train if c != "TARGET"]
for c in predictor_lst:
    evaluate(c)
# Out:
# ========MA_5========
# MSE: 5.577465918627202
# Directional Accuracy: 0.5026358475263585
# MAPE: 250.5248023280729
# ========MA_25========
# MSE: 4.789932876015388
# Directional Accuracy: 0.5028386050283861
# MAPE: 151.2560410964795
# ========MA_50========
# MSE: 4.707950884150765
# Directional Accuracy: 0.4955393349553934
# MAPE: 136.18623736160743
# ========MA_100========
# MSE: 4.687995875022585
# Directional Accuracy: 0.4906731549067315
# MAPE: 118.1624599492316
# ========NAIVE========
# MSE: 4.632635694214761
# Directional Accuracy: 0.007096512570965126
# MAPE: 99.29034874290349
